# %% [markdown]
# # Pratique des modèles linéaires généralisés <a class="tocSkip">

# %% [markdown]
# Cette série d'exercices vise à participer à la compréhension de la théorie des GLM, à mettre en oeuvre les méthodes sous Python, dans différents cas de figures de modèles statistiques et de jeux de données.
# On utilisera la librairie statsmodels, qui permet d'obtenir des résultats suivant une syntaxe et des présentations proches de celles de R.
#
# De plus, votre serviteur vous fournit plusieurs fonctions utilitaires pour afficher des résumés statistiques et des graphiques dans la librairie `GLMRegression_in_Python_like_in_R`. Vous êtes invités à consulter le source des fonctions qui vous sont fournies.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Préparation" data-toc-modified-id="Préparation-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Préparation</a></span></li><li><span><a href="#Proba-de-survie-sur-le-Titanic" data-toc-modified-id="Proba-de-survie-sur-le-Titanic-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Proba de survie sur le Titanic</a></span><ul class="toc-item"><li><span><a href="#Lecture-et-analyse-des-données" data-toc-modified-id="Lecture-et-analyse-des-données-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lecture et analyse des données</a></span></li><li><span><a href="#Modèle-de-régression-logistique" data-toc-modified-id="Modèle-de-régression-logistique-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Modèle de régression logistique</a></span></li><li><span><a href="#Régression-binomiale" data-toc-modified-id="Régression-binomiale-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Régression binomiale</a></span><ul class="toc-item"><li><span><a href="#Données-binomiales" data-toc-modified-id="Données-binomiales-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Données binomiales</a></span></li></ul></li><li><span><a href="#Regroupements" data-toc-modified-id="Regroupements-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Regroupements</a></span></li><li><span><a href="#Régressions-binomiales" data-toc-modified-id="Régressions-binomiales-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Régressions binomiales</a></span></li></ul></li><li><span><a href="#Crimes-sur-les-campus" data-toc-modified-id="Crimes-sur-les-campus-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Crimes sur les campus</a></span><ul class="toc-item"><li><span><a href="#Lecture-et-analyse" data-toc-modified-id="Lecture-et-analyse-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Lecture et analyse</a></span></li><li><span><a href="#Modèle-de-Poisson" data-toc-modified-id="Modèle-de-Poisson-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Modèle de Poisson</a></span><ul class="toc-item"><li><span><a href="#Notion-de--modèle-de-Poisson-et-d'offset" data-toc-modified-id="Notion-de--modèle-de-Poisson-et-d'offset-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Notion de  modèle de Poisson et d'offset</a></span></li><li><span><a href="#Régression-de-Poisson" data-toc-modified-id="Régression-de-Poisson-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Régression de Poisson</a></span></li><li><span><a href="#Régression-avec-une-binomiale-négative" data-toc-modified-id="Régression-avec-une-binomiale-négative-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Régression avec une binomiale négative</a></span></li></ul></li></ul></li><li><span><a href="#Réussite-en-maths" data-toc-modified-id="Réussite-en-maths-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Réussite en maths</a></span><ul class="toc-item"><li><span><a href="#Lecture-et-analyse" data-toc-modified-id="Lecture-et-analyse-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Lecture et analyse</a></span></li><li><span><a href="#Régression" data-toc-modified-id="Régression-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Régression</a></span></li></ul></li><li><span><a href="#Richesse-écologique" data-toc-modified-id="Richesse-écologique-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Richesse écologique</a></span><ul class="toc-item"><li><span><a href="#Lecture-et-analyse" data-toc-modified-id="Lecture-et-analyse-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Lecture et analyse</a></span><ul class="toc-item"><li><span><a href="#Tracés" data-toc-modified-id="Tracés-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Tracés</a></span></li><li><span><a href="#Tests-statistiques" data-toc-modified-id="Tests-statistiques-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Tests statistiques</a></span></li></ul></li><li><span><a href="#Premier-modèle." data-toc-modified-id="Premier-modèle.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Premier modèle.</a></span></li><li><span><a href="#2e-modèle" data-toc-modified-id="2e-modèle-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>2e modèle</a></span></li><li><span><a href="#diagnostic" data-toc-modified-id="diagnostic-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>diagnostic</a></span><ul class="toc-item"><li><span><a href="#Tracez-les-quelques-figures-de-diagnostic" data-toc-modified-id="Tracez-les-quelques-figures-de-diagnostic-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Tracez les quelques figures de diagnostic</a></span></li><li><span><a href="#Exploitation-des-prédictions" data-toc-modified-id="Exploitation-des-prédictions-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Exploitation des prédictions</a></span></li></ul></li></ul></li><li><span><a href="#Quine-Data" data-toc-modified-id="Quine-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Quine Data</a></span></li><li><span><a href="#Régression-linéaire" data-toc-modified-id="Régression-linéaire-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Régression linéaire</a></span></li></ul></div>

# %%
import pandas as pd 
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
#
from GLMRegression_in_Python_like_in_R import GLMsummary, glm_residplot
from LinearRegression_in_Python_like_in_R_2023 import lm, summary, vif

# %% [markdown]
# ## Préparation
#
# Consulter la description et la syntaxe de la fonction GLM de statsmodels à cette adresse : https://www.statsmodels.org/stable/glm.html
# Avec les méthodes et attributs associés au modèle : https://www.statsmodels.org/stable/generated/statsmodels.genmod.generalized_linear_model.GLMResults.html#statsmodels.genmod.generalized_linear_model.GLMResults
#
# Vous pourrez également consulter avec intérêt l'aide du pendant R. : https://www.rdocumentation.org/packages/stats/versions/3.6.2/topics/glm
#
# Il est possible d'utiliser l'approche "formule" dans glm ou lm (modèle linéaire) : celle-ci consiste à préciser la variable réponse et les variables indépendantes. Prenez le temps de consulter la syntaxe ici : https://www.statsmodels.org/stable/example_formulas.html
# Vous pourrez effectuer quelque chose comme
# ```
# glm('response ~ predictor1 + predictor2 + C(predictor3) + predictor4*predictor5 -1', data=DATA, family=...)
# ```

# %% [markdown]
# ## Proba de survie sur le Titanic

# %% [markdown]
# Dans cet exercice, nous allons revoir la régression logistique, sous l'angle d'un GLM, puis transformer le problème pour faire apparaître une véritable régression biomiale, qui sera bien entendu traitée avec un GLM.
#
# Cet exercice est inspiré du post suivant :
# https://towardsdatascience.com/the-binomial-regression-model-everything-you-need-to-know-5216f1a483d3
# dans lequel il y a des choses intéressantes, mais également d'autres assez discutables.

# %% [markdown]
# ### Lecture et analyse des données

# %% [markdown]
# >Vous commencerez par charger le fichier de données, `titanic.csv`, afficherez les premères lignes et les infos de type des données. Quelles sont les données quantitatives, catégorielles, ordinales ?

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# > Pour des questions pratiques, renommer les colonnes `'Siblings/Spouses Aboard', 'Parents/Children Aboard'` en
# `'ParentsChildrenAboard', 'SiblingsSpousesAboard'`

# %%
name_changes = {'Siblings/Spouses Aboard' : 'SiblingsSpousesAboard', 
                'Parents/Children Aboard' : 'ParentsChildrenAboard'}

# %%
df = df.rename(columns=name_changes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Survived               887 non-null    int64
#  1   Pclass                 887 non-null    int64
#  2   Name                   887 non-null    object
#  3   Sex                    887 non-null    object
#  4   Age                    887 non-null    float64
#  5   SiblingsSpousesAboard  887 non-null    int64
#  6   ParentsChildrenAboard  887 non-null    int64
#  7   Fare                   887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
df.Pclass = df.Pclass.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Survived               887 non-null    int64
#  1   Pclass                 887 non-null    category
#  2   Name                   887 non-null    object
#  3   Sex                    887 non-null    object
#  4   Age                    887 non-null    float64
#  5   SiblingsSpousesAboard  887 non-null    int64
#  6   ParentsChildrenAboard  887 non-null    int64
#  7   Fare                   887 non-null    float64
# dtypes: category(1), float64(2), int64(3), object(2)
# memory usage: 49.6+ KB

# %% [markdown]
# ### Modèle de régression logistique

# %% [markdown]
# >On s'intéresse évidemment à la survie en fonction des autres paramètres. La variable `Survived` est une variable binaire (de Bernouilli) ; et on va mettre en oeuvre une régressoin logistique comme on l'a vu lors du TP précédent.
# >
# >Simplement, plutôt que de construire les matrices endog et exog, nous allons utiliser la version "formule" en utilisant la méthode `smf.glm(..)`.
# >
# >  -  a) Utiliser cette fonction pour définir le modèle puis l'apprendre.
# >  -  b) Vous pourrez ensuite afficher les caractéristiques  avec la méthode `.summary()` ou utiliser la fonction fournie `GLMsummary`.

# %%
glm_titanic = smf.glm("Survived ~  Sex + Age + C(Pclass) + Fare + SiblingsSpousesAboard + ParentsChildrenAboard", 
                      df, family=sm.families.Binomial())

res = glm_titanic.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                              coef    std err          z   P>|z|     [0.025  \
# Intercept                  4.1098      0.464      8.865   0.000      3.201
# Sex[T.male]               -2.7567      0.201    -13.739   0.000     -3.150
# C(Pclass)[T.2]            -1.1615      0.301     -3.859   0.000     -1.751
# C(Pclass)[T.3]            -2.3500      0.305     -7.713   0.000     -2.947
# Age                       -0.0434      0.008     -5.573   0.000     -0.059
# Fare                       0.0028      0.002      1.144   0.253     -0.002
# SiblingsSpousesAboard     -0.4016      0.111     -3.624   0.000     -0.619
# ParentsChildrenAboard     -0.1069      0.119     -0.900   0.368     -0.340
#
#                           0.975]       p-value Code
# Intercept                  5.018  7.658732e-19  ***
# Sex[T.male]               -2.363  5.894600e-43  ***
# C(Pclass)[T.2]            -0.572  1.137166e-04  ***
# C(Pclass)[T.3]            -1.753  1.224785e-14  ***
# Age                       -0.028  2.507098e-08  ***
# Fare                       0.008  2.527710e-01
# SiblingsSpousesAboard     -0.184  2.895733e-04  ***
# ParentsChildrenAboard      0.126  3.681513e-01
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 8 ddl = 796.93

# %% [markdown]
# > Quelles sont les variables qui ne semblent pas significatives ? Supprimez les du modèle et réitérez.

# %%
# ParentsdChildrenAboard - Fare
glm_titanic = smf.glm("Survived ~  Sex + Age + C(Pclass) + SiblingsSpousesAboard", 
                      df, family=sm.families.Binomial())

res = glm_titanic.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                              coef    std err          z   P>|z|     [0.025  \
# Intercept                  4.2942      0.418     10.276   0.000      3.475
# Sex[T.male]               -2.7380      0.196    -13.984   0.000     -3.122
# C(Pclass)[T.2]            -1.3217      0.268     -4.923   0.000     -1.848
# C(Pclass)[T.3]            -2.5412      0.258     -9.837   0.000     -3.048
# Age                       -0.0439      0.008     -5.662   0.000     -0.059
# SiblingsSpousesAboard     -0.4096      0.105     -3.883   0.000     -0.616
#
#                           0.975]       p-value Code
# Intercept                  5.113  9.031289e-25  ***
# Sex[T.male]               -2.354  1.950941e-44  ***
# C(Pclass)[T.2]            -0.796  8.503827e-07  ***
# C(Pclass)[T.3]            -2.035  7.767738e-23  ***
# Age                       -0.029  1.500237e-08  ***
# SiblingsSpousesAboard     -0.203  1.032303e-04  ***
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 6 ddl = 794.82

# %% [markdown]
# > Comparez les AIC dans les deux cas. Ceci confirme-t-il l'intérêt de supprimer ces variables ?

# %%
# AIC = −2×log-likelihood + 2×number of parameters

diff = (abs(796.93 - 794.82) / max(796.93,794.82)) * 100

diff
# Out:
# 0.26476603967724893

# %% [markdown]
# > calculer la table de confusion, avec un seuil à 0.5, et l'*accuracy* (utiliser par exemple pandas crosstab, `pd.crosstab()`)

# %%
predictions = res.predict()
predictions
# Out:
# array([0.08620151, 0.90164545, 0.64818071, 0.91272718, 0.07431382,
#        0.10239516, 0.30672976, 0.09097389, 0.63810146, 0.87522651,
#        0.76271713, 0.85156101, 0.13430014, 0.04279744, 0.75732579,
#        0.63574633, 0.06230252, 0.31525099, 0.49545891, 0.68712787,
#        0.21371011, 0.22118285, 0.74916337, 0.58088996, 0.54307091,
#        0.41931299, 0.10650279, 0.37585513, 0.66794137, 0.11970607,
#        0.45001898, 0.85525891, 0.72360202, 0.06512051, 0.47921287,
#        0.33224354, 0.14484431, 0.12927553, 0.5357268 , 0.67446491,
#        0.39808966, 0.79851558, 0.91916726, 0.71473255, 0.09090406,
#        0.09337668, 0.63810146, 0.07536642, 0.63477928, 0.05064136,
#        0.12927553, 0.84973692, 0.78401267, 0.21440812, 0.38601248,
#        0.88596556, 0.09649694, 0.91239613, 0.02885153, 0.12441189,
#        0.93247011, 0.30368509, 0.08396625, 0.22189837, 0.15418531,
#        0.84538183, 0.13948876, 0.34701662, 0.04991544, 0.23668338,
#        0.2693575 , 0.33451235, 0.07333213, 0.08390131, 0.11075487,
#        0.11970607, 0.0984285 , 0.54933633, 0.60715713, 0.12441189,
#        0.09459931, 0.59663398, 0.58088996, 0.90254709, 0.28388929,
#        0.10934867, 0.13430014, 0.8864691 , 0.11515484, 0.09459931,
#        0.13430014, 0.29447892, 0.07333213, 0.02721799, 0.12441189,
#        0.17335024, 0.63321176, 0.81445735, 0.15863616, 0.62789921,
#        0.09459931, 0.65336356, 0.08058675, 0.03139148, 0.0984285 ,
#        0.69649115, 0.09459931, 0.06574328, 0.52836715, 0.375657  ,
#        0.66962515, 0.12441189, 0.61418506, 0.732299  , 0.12927553,
#        0.01660439, 0.19018347, 0.62295312, 0.50664918, 0.18136973,
#        0.13948876, 0.16762787, 0.82420707, 0.30672976, 0.12766793,
#        0.13948876, 0.11515484, 0.77824552, 0.04919939, 0.08058675,
#        0.13430014, 0.3272035 , 0.78401267, 0.2966044 , 0.31525099,
#        0.96951964, 0.38261516, 0.15606707, 0.62295312, 0.49904827,
#        0.68712787, 0.57181607, 0.13948876, 0.36445245, 0.26705156,
#        0.10239516, 0.63144421, 0.20284891, 0.16656995, 0.11863704,
#        0.94874556, 0.03159758, 0.05931255, 0.10239516, 0.33543659,
#        0.74082035, 0.09090406, 0.0684928 , 0.01118783, 0.05129499,
#        0.7713106 , 0.10650279, 0.15036954, 0.06491813, 0.20095155,
#        0.89899269, 0.34682525, 0.25370217, 0.0984285 , 0.24547706,
#        0.05736404, 0.78573225, 0.12927553, 0.28837492, 0.10108303,
#        0.08064936, 0.89073249, 0.25291743, 0.07134852, 0.132917  ,
#        0.18567239, 0.0465813 , 0.34779966, 0.82881591, 0.46091105,
#        0.55018732, 0.39647214, 0.04103398, 0.07134852, 0.82736612,
#        0.35434157, 0.62453848, 0.42386235, 0.91386413, 0.85156101,
#        0.0984285 , 0.05574188, 0.69649115, 0.87196238, 0.0984285 ,
#        0.00663526, 0.07739208, 0.04818227, 0.14484431, 0.84092083,
#        0.05731838, 0.10650279, 0.74082035, 0.45001898, 0.11515484,
#        0.8077287 , 0.12441189, 0.25291743, 0.08620151, 0.9257435 ,
#        0.63810146, 0.11714394, 0.94728888, 0.25291743, 0.15606707,
#        0.27861196, 0.03823811, 0.12441189, 0.37229556, 0.12441189,
#        0.35434157, 0.13176752, 0.36445245, 0.49925944, 0.91272718,
#        0.09459931, 0.08653084, 0.47373491, 0.30584821, 0.69649115,
#        0.10836075, 0.93220839, 0.35434157, 0.22884083, 0.62453848,
#        0.63477928, 0.26130551, 0.12441189, 0.09090406, 0.23227376,
#        0.65812964, 0.87196238, 0.38261516, 0.07264307, 0.14484431,
#        0.51741098, 0.23743376, 0.06225319, 0.48807091, 0.61758172,
#        0.93247011, 0.95150641, 0.94030872, 0.68493426, 0.05978555,
#        0.24282744, 0.45001898, 0.69649115, 0.20642293, 0.03468041,
#        0.07637309, 0.85156101, 0.94030872, 0.58088996, 0.11075487,
#        0.76347165, 0.48279715, 0.57532782, 0.7535582 , 0.44438128,
#        0.33451235, 0.05064136, 0.45169146, 0.02104561, 0.0984285 ,
#        0.15606707, 0.13948876, 0.27944661, 0.08058675, 0.09090406,
#        0.12441189, 0.16656995, 0.68712787, 0.95899881, 0.95478657,
#        0.20642293, 0.66794137, 0.11515484, 0.55936636, 0.11741134,
#        0.97804816, 0.375657  , 0.89073249, 0.70569423, 0.05424957,
#        0.13948876, 0.72156051, 0.0984285 , 0.75140432, 0.92053168,
#        0.95843052, 0.18351128, 0.95150641, 0.96231667, 0.9360991 ,
#        0.80548901, 0.0984285 , 0.11267765, 0.64818071, 0.81888298,
#        0.10553753, 0.94943926, 0.8935765 , 0.12441189, 0.10239516,
#        0.83955372, 0.83154753, 0.00582094, 0.93779546, 0.02498642,
#        0.8008157 , 0.49545891, 0.97318137, 0.42652736, 0.39122982,
#        0.47184057, 0.07536642, 0.88493007, 0.09090406, 0.46826398,
#        0.92368569, 0.04919939, 0.39647214, 0.43462163, 0.88197349,
#        0.2698713 , 0.2966044 , 0.20642293, 0.87196238, 0.7713106 ,
#        0.46258996, 0.17851058, 0.05574188, 0.11970607, 0.41766907,
#        0.11369991, 0.07637309, 0.11970607, 0.0984285 , 0.96537573,
#        0.78643408, 0.68712787, 0.67760944, 0.04103398, 0.19018347,
#        0.44438128, 0.07431382, 0.07040303, 0.09090406, 0.77720219,
#        0.55373802, 0.68712787, 0.96231667, 0.51213736, 0.10108303,
#        0.13948876, 0.64335109, 0.59683724, 0.94194647, 0.68712787,
#        0.59154265, 0.13430014, 0.13948876, 0.92053168, 0.84670835,
#        0.08390131, 0.91272718, 0.10239516, 0.36445245, 0.04406048,
#        0.8008157 , 0.13948876, 0.90254709, 0.3930417 , 0.12927553,
#        0.04591076, 0.94656733, 0.66794137, 0.12441189, 0.59663398,
#        0.1435874 , 0.31525099, 0.8510358 , 0.06309666, 0.10650279,
#        0.6037273 , 0.06758239, 0.70569423, 0.15863616, 0.03823811,
#        0.42386235, 0.12927553, 0.59683724, 0.05574188, 0.10239516,
#        0.91947499, 0.32480758, 0.05129499, 0.58602114, 0.74452331,
#        0.89861532, 0.25291743, 0.78813959, 0.12927553, 0.09459931,
#        0.52836715, 0.10108303, 0.03367679, 0.7913569 , 0.89454346,
#        0.0984285 , 0.08390131, 0.58088996, 0.47352433, 0.67222487,
#        0.15036954, 0.25933973, 0.9633741 , 0.50284889, 0.75010522,
#        0.15919071, 0.24470941, 0.6425639 , 0.13430014, 0.07637309,
#        0.8510358 , 0.09459931, 0.79906671, 0.91694356, 0.51572404,
#        0.67130459, 0.32571813, 0.14726089, 0.06758239, 0.55936636,
#        0.26786444, 0.11515484, 0.09459931, 0.21440812, 0.8893272 ,
#        0.68493426, 0.15036954, 0.36541399, 0.07739208, 0.375657  ,
#        0.13312049, 0.07739208, 0.06574328, 0.33451235, 0.28837492,
#        0.12441189, 0.71110258, 0.06309666, 0.06574328, 0.7527869 ,
#        0.87678604, 0.68712787, 0.45001898, 0.15863616, 0.06486688,
#        0.12441189, 0.84092083, 0.03141717, 0.19932124, 0.03988642,
#        0.26621104, 0.51213736, 0.54307091, 0.91272718, 0.27068958,
#        0.09090406, 0.14307492, 0.0971617 , 0.12927553, 0.29747072,
#        0.17335024, 0.12927553, 0.10650279, 0.81949751, 0.03227647,
#        0.94194647, 0.11515484, 0.15036954, 0.69649115, 0.69649115,
#        0.53194357, 0.97318137, 0.58806898, 0.82100272, 0.48279715,
#        0.0984285 , 0.10650279, 0.09459931, 0.02015955, 0.49377031,
#        0.81949751, 0.11515484, 0.375657  , 0.81445735, 0.09090406,
#        0.72746048, 0.08390131, 0.95150641, 0.12441189, 0.07431382,
#        0.91386413, 0.14484431, 0.05931255, 0.68493426, 0.35529134,
#        0.06309666, 0.16869115, 0.92237086, 0.15036954, 0.10514419,
#        0.66794137, 0.60715713, 0.93493173, 0.39647214, 0.95150641,
#        0.01771505, 0.96537573, 0.93779546, 0.43025003, 0.4088629 ,
#        0.17071422, 0.25933973, 0.22189837, 0.8492064 , 0.27861196,
#        0.05499096, 0.37132651, 0.69200959, 0.27861196, 0.12927553,
#        0.12441189, 0.68712787, 0.23743376, 0.85525891, 0.39647214,
#        0.89768143, 0.44083911, 0.09090406, 0.06054968, 0.2698713 ,
#        0.06054968, 0.27487779, 0.05424957, 0.13948876, 0.61758172,
#        0.0984285 , 0.08390131, 0.07666802, 0.75900661, 0.49377031,
#        0.68712787, 0.15606707, 0.13948876, 0.81445735, 0.89768143,
#        0.63477928, 0.08390131, 0.81227783, 0.89768143, 0.10553753,
#        0.49377031, 0.15606707, 0.97079106, 0.13827081, 0.18413375,
#        0.12441189, 0.12441189, 0.07431382, 0.8321279 , 0.04524942,
#        0.49904827, 0.14183082, 0.04853207, 0.83354917, 0.04160271,
#        0.14484431, 0.26786444, 0.75010522, 0.05574188, 0.48279715,
#        0.05129499, 0.50474946, 0.04853207, 0.09090406, 0.59154265,
#        0.83154753, 0.92672449, 0.40865877, 0.12927553, 0.63477928,
#        0.12441189, 0.07431382, 0.81888298, 0.05275275, 0.55018732,
#        0.87841903, 0.28752425, 0.07040303, 0.33224354, 0.09337668,
#        0.12927553, 0.12927553, 0.24547706, 0.09373061, 0.9668141 ,
#        0.10650279, 0.14484431, 0.12375592, 0.03823811, 0.53761725,
#        0.55936636, 0.53215387, 0.8510358 , 0.08390131, 0.177022  ,
#        0.48807091, 0.0465438 , 0.13430014, 0.96231667, 0.60735859,
#        0.08390131, 0.71110258, 0.27656473, 0.13948876, 0.28837492,
#        0.12927553, 0.67760944, 0.11970607, 0.89861532, 0.12927553,
#        0.74082035, 0.72360202, 0.16262156, 0.10239516, 0.48448415,
#        0.31525099, 0.27068958, 0.18861612, 0.06054968, 0.375657  ,
#        0.07134852, 0.09337668, 0.12023589, 0.2966044 , 0.04160271,
#        0.05347484, 0.85525891, 0.69127826, 0.44646797, 0.05520825,
#        0.24470941, 0.35434157, 0.14484431, 0.11293616, 0.72360202,
#        0.36698185, 0.49377031, 0.62789921, 0.59154265, 0.13430014,
#        0.02538036, 0.05677057, 0.21871944, 0.03774424, 0.13948876,
#        0.14484431, 0.9743041 , 0.44646797, 0.82881591, 0.0684928 ,
#        0.11075487, 0.25370217, 0.11412118, 0.05129499, 0.71473255,
#        0.26786444, 0.05574188, 0.95664508, 0.50474946, 0.72360202,
#        0.11075487, 0.07333213, 0.18567239, 0.73029779, 0.42838803,
#        0.96537573, 0.17216085, 0.96231667, 0.43917462, 0.27656473,
#        0.09459931, 0.11412118, 0.13948876, 0.93247011, 0.85651812,
#        0.08058675, 0.93755299, 0.10514419, 0.22118285, 0.12330671,
#        0.49018176, 0.13430014, 0.60492726, 0.62789921, 0.21871944,
#        0.56103068, 0.95349318, 0.18721716, 0.1727565 , 0.31525099,
#        0.31525099, 0.09649694, 0.31760957, 0.50474946, 0.13430014,
#        0.08390131, 0.39647214, 0.3930417 , 0.92775017, 0.07952932,
#        0.08733924, 0.12699729, 0.10934867, 0.83955372, 0.57739041,
#        0.08733924, 0.91584352, 0.22294218, 0.08058675, 0.11970607,
#        0.61176899, 0.44902577, 0.0984285 , 0.36445245, 0.07739208,
#        0.94505234, 0.11970607, 0.05809913, 0.13430014, 0.9091648 ,
#        0.15606707, 0.83817376, 0.38601248, 0.60190733, 0.06758239,
#        0.08390131, 0.11515484, 0.04338951, 0.61517359, 0.09459931,
#        0.54766564, 0.14484431, 0.13430014, 0.82249448, 0.12441189,
#        0.91725898, 0.76530581, 0.95843052, 0.57016131, 0.05060077,
#        0.11075487, 0.11075487, 0.72360202, 0.04857109, 0.19175694,
#        0.38601248, 0.13430014, 0.38502962, 0.07970587, 0.41766907,
#        0.11075487, 0.18567239, 0.89493421, 0.59663398, 0.09090406,
#        0.50643805, 0.22118285, 0.76876813, 0.66002772, 0.26824654,
#        0.10239516, 0.08733924, 0.46091105, 0.72360202, 0.18567239,
#        0.91947499, 0.10650279, 0.06309666, 0.21371011, 0.46279996,
#        0.08910557, 0.46091105, 0.67760944, 0.177022  , 0.05347484,
#        0.06579518, 0.8321279 , 0.10239516, 0.47184057, 0.63810146,
#        0.06230252, 0.07134852, 0.11970607, 0.5474873 , 0.13948876,
#        0.82795791, 0.6647492 , 0.44728792, 0.09090406, 0.11970607,
#        0.14484431, 0.89768143, 0.12927553, 0.13430014, 0.08390131,
#        0.57016131, 0.13430014, 0.38502962, 0.95150641, 0.07583861,
#        0.15036954, 0.05574188, 0.00635197, 0.07431382, 0.2698713 ,
#        0.8935765 , 0.05736404, 0.0142723 , 0.7207212 , 0.97318137,
#        0.65258654, 0.72360202, 0.87081827, 0.33543659, 0.66794137,
#        0.09090406, 0.02646791, 0.25021413, 0.89899269, 0.10537109,
#        0.30584821, 0.75544919, 0.79851558, 0.54851497, 0.11970607,
#        0.17216085, 0.10650279, 0.86061126, 0.52668347, 0.04524942,
#        0.7913569 , 0.74916337, 0.13430014, 0.13948876, 0.11970607,
#        0.86232473, 0.86697853, 0.08058675, 0.68712787, 0.2698713 ,
#        0.11075487, 0.51002655, 0.27861196, 0.96951964, 0.73805403,
#        0.60211005, 0.08390131])

# %%
tab = pd.crosstab(df['Survived'], predictions>0.5)
tab
# Out:
# col_0     False  True
# Survived
# 0           472     73
# 1           100    242

# %%
accuracy = np.sum(np.diag(tab))/np.sum(np.sum(tab))
accuracy
# Out:
# C:\Users\lucas\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# 0.8049605411499436

# %% [markdown]
# ### Régression binomiale

# %% [markdown]
# Il y a parfois des observations multiples correspondant à une même situation : par exemples deux hommes de même age, dans la même classe et avec leur épouse à bord. Avec deux résultats de survie différents. A l'intérieur d'une même catégorie, on va donc avoir des survivants et d'autre pas. Il s'agit d'un ensemble de résultats de Bernouilli, et ceci correspond à un loi binomiale, qui mesure le nombre de "succès" (ou d'échecs) parmi $n$ essais.

# %% [markdown]
# Pour être plus proche de cette situation, nous allons transformer les données afin d'obtenir des catégories plus importantes (quantitativement) et peut-être rendre la prédiction plus robuste d'ailleurs.

# %% [markdown]
# #### Données binomiales
# > On va créer des catégories d'age de 5 ans (de 0 à5, de 5 à 10, de 10 à 15, etc). Vous utiliserez pour ce faire la fonction `pd.cut(..)` etg ajouterez une colonne `Age_Range`à notre dataframe.

# %%
#define the bins
age_range_bins=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
#define the label for each bin. Num labels = Num bins - 1
age_range_labels=[5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
#Cut up the age range into multiple bins and stuff them into a new Age_Range column
df['Age_Range'] = pd.cut(df['Age'], age_range_bins, labels=age_range_labels)
df
# Out:
#      Survived Pclass                                               Name  \
# 0           0      3                             Mr. Owen Harris Braund
# 1           1      1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1      3                              Miss. Laina Heikkinen
# 3           1      1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0      3                            Mr. William Henry Allen
# ..        ...    ...                                                ...
# 882         0      2                               Rev. Juozas Montvila
# 883         1      1                        Miss. Margaret Edith Graham
# 884         0      3                     Miss. Catherine Helen Johnston
# 885         1      1                               Mr. Karl Howell Behr
# 886         0      3                                 Mr. Patrick Dooley
#
#         Sex   Age  SiblingsSpousesAboard  ParentsChildrenAboard     Fare  \
# 0      male  22.0                      1                      0   7.2500
# 1    female  38.0                      1                      0  71.2833
# 2    female  26.0                      0                      0   7.9250
# 3    female  35.0                      1                      0  53.1000
# 4      male  35.0                      0                      0   8.0500
# ..      ...   ...                    ...                    ...      ...
# 882    male  27.0                      0                      0  13.0000
# 883  female  19.0                      0                      0  30.0000
# 884  female   7.0                      1                      2  23.4500
# 885    male  26.0                      0                      0  30.0000
# 886    male  32.0                      0                      0   7.7500
#
#     Age_Range
# 0          25
# 1          40
# 2          30
# 3          35
# 4          35
# ..        ...
# 882        30
# 883        20
# 884        10
# 885        30
# 886        35
#
# [887 rows x 9 columns]

# %% [markdown]
# ### Regroupements

# %% [markdown]
# > On va maintenant regrouper les données par mêmes (Class, Sex, et Age_Range).
# > Il s'agira de compter a) le nombre d'individus dans chacune de ces catégories, b)le nombre de survivants (et par différence de morts). Il vous faut obtenir un tableau ['Pclass', 'Sex', 'Age_Range', 'Survived', 'Died', 'Total']. On peut s'y prendre avec des groupby, et utiliser les fonctions d'aggrégation 'sum' et 'count'. On peut aussi faire cela avec une table croisée dynamique `pivot_table`

# %% [markdown]
# > Si vous utilisez la table croisée, les commandes suivantes
# >```
# pt.columns = pt.columns.to_flat_index()
# pt.reset_index(inplace=True)
# >```
# >permettent d'applatir les index de colonne et de lignes.

# %%
pt = pd.pivot_table(df, values="Survived", index=['Pclass', 'Sex', 'Age_Range'], aggfunc=['sum', 'count'])

# %%
pt
# Out:
#                              sum    count
#                         Survived Survived
# Pclass Sex    Age_Range
# 1      female 5                0        1
#               10               0        0
#               15               2        2
#               20              11       11
#               25              14       15
# ...                          ...      ...
# 3      male   60               0        2
#               65               0        2
#               70               0        2
#               75               0        2
#               80               0        0
#
# [96 rows x 2 columns]

# %%
pt.columns = pt.columns.to_flat_index()
pt.reset_index(inplace=True)
pt
# Out:
#    Pclass     Sex Age_Range  (sum, Survived)  (count, Survived)
# 0       1  female         5                0                  1
# 1       1  female        10                0                  0
# 2       1  female        15                2                  2
# 3       1  female        20               11                 11
# 4       1  female        25               14                 15
# ..    ...     ...       ...              ...                ...
# 91      3    male        60                0                  2
# 92      3    male        65                0                  2
# 93      3    male        70                0                  2
# 94      3    male        75                0                  2
# 95      3    male        80                0                  0
#
# [96 rows x 5 columns]

# %%
pt.columns = ['Pclass', 'Sex', 'Age_Range', 'Survived', 'Total']
pt['Died'] = pt['Total'] - pt['Survived'] 
pt
# Out:
#    Pclass     Sex Age_Range  Survived  Total  Died
# 0       1  female         5         0      1     1
# 1       1  female        10         0      0     0
# 2       1  female        15         2      2     0
# 3       1  female        20        11     11     0
# 4       1  female        25        14     15     1
# ..    ...     ...       ...       ...    ...   ...
# 91      3    male        60         0      2     2
# 92      3    male        65         0      2     2
# 93      3    male        70         0      2     2
# 94      3    male        75         0      2     2
# 95      3    male        80         0      0     0
#
# [96 rows x 6 columns]

# %% [markdown]
# > Lorsque votre table a été créée, contrôler quels sont le stypes de vos différentes colonnes. Age_range et Sex devraient être des catégories

# %%
pt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pclass     96 non-null     category
#  1   Sex        96 non-null     object
#  2   Age_Range  96 non-null     category
#  3   Survived   96 non-null     int64
#  4   Total      96 non-null     int64
#  5   Died       96 non-null     int64
# dtypes: category(2), int64(3), object(1)
# memory usage: 4.1+ KB

# %%
pt.Sex = pt.Sex.astype('category')
pt.Pclass = pt.Pclass.astype('category')

# %%
pt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pclass     96 non-null     category
#  1   Sex        96 non-null     category
#  2   Age_Range  96 non-null     category
#  3   Survived   96 non-null     int64
#  4   Total      96 non-null     int64
#  5   Died       96 non-null     int64
# dtypes: category(3), int64(3)
# memory usage: 3.6 KB

# %% [markdown]
# ### Régressions binomiales

# %% [markdown]
# > Mettre en oeuvre une régression binomiale en cherchant à modéliser le couple (Survie, Décès). Ceci conduit le glm à modéliser la proportion des Survies. Pour utiliser le glm, il faut spécifier `Survived + Died ~ ` dans la formule.

# %%
# Si vous rencontrez l'erreur 
# ValueError: The first guess on the deviance function returned a nan.  
# This could be a boundary  problem and should be reported.
pt.Survived = pt.Survived.astype('float')
pt.Died = pt.Died.astype('float')
pt.Total = pt.Total.astype('float')

I = pt.Total == 0
pt.loc[I, 'Survived'] = 1e-15
pt.loc[I, 'Died'] = 1e-15
pt.loc[I, 'Total'] = 1e-15

# %%
model = smf.glm( 'Survived + Died ~ Pclass + Age_Range + Sex', data=pt, family=sm.families.Binomial())
res = model.fit()

# %% [markdown]
# > Afficher les résumés des résulats avec `GLMsummary`

# %%
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                        coef    std err          z   P>|z|     [0.025  \
# Intercept            4.4720      0.475      9.422   0.000      3.542
# Pclass[T.2]         -1.2785      0.274     -4.670   0.000     -1.815
# Pclass[T.3]         -2.4451      0.263     -9.285   0.000     -2.961
# Age_Range[T.10]     -2.0555      0.637     -3.225   0.001     -3.305
# Age_Range[T.15]     -1.5214      0.654     -2.326   0.020     -2.803
# Age_Range[T.20]     -1.6749      0.441     -3.801   0.000     -2.539
# Age_Range[T.25]     -1.8930      0.427     -4.428   0.000     -2.731
# Age_Range[T.30]     -1.5897      0.427     -3.721   0.000     -2.427
# Age_Range[T.35]     -1.1639      0.447     -2.601   0.009     -2.041
# Age_Range[T.40]     -2.2660      0.480     -4.721   0.000     -3.207
# Age_Range[T.45]     -2.3689      0.520     -4.552   0.000     -3.389
# Age_Range[T.50]     -2.2768      0.535     -4.258   0.000     -3.325
# Age_Range[T.55]     -2.4528      0.666     -3.683   0.000     -3.758
# Age_Range[T.60]     -2.9873      0.722     -4.139   0.000     -4.402
# Age_Range[T.65]     -3.1584      0.779     -4.052   0.000     -4.686
# Age_Range[T.70]    -23.1383   1.99e+04     -0.001   0.999  -3.91e+04
# Age_Range[T.75]    -23.5027   2.13e+04     -0.001   0.999  -4.18e+04
# Age_Range[T.80]     20.7755   4.82e+04      0.000   1.000  -9.44e+04
# Sex[T.male]         -2.6814      0.196    -13.710   0.000     -3.065
#
#                     0.975]       p-value Code
# Intercept            5.402  4.443562e-21  ***
# Pclass[T.2]         -0.742  3.008150e-06  ***
# Pclass[T.3]         -1.929  1.610693e-20  ***
# Age_Range[T.10]     -0.806  1.259550e-03   **
# Age_Range[T.15]     -0.239  2.001744e-02    *
# Age_Range[T.20]     -0.811  1.440349e-04  ***
# Age_Range[T.25]     -1.055  9.504195e-06  ***
# Age_Range[T.30]     -0.752  1.981227e-04  ***
# Age_Range[T.35]     -0.287  9.297435e-03   **
# Age_Range[T.40]     -1.325  2.352508e-06  ***
# Age_Range[T.45]     -1.349  5.310501e-06  ***
# Age_Range[T.50]     -1.229  2.066154e-05  ***
# Age_Range[T.55]     -1.148  2.301687e-04  ***
# Age_Range[T.60]     -1.573  3.483500e-05  ***
# Age_Range[T.65]     -1.631  5.079994e-05  ***
# Age_Range[T.70]    3.9e+04  9.990734e-01
# Age_Range[T.75]   4.18e+04  9.991209e-01
# Age_Range[T.80]   9.45e+04  9.996561e-01
# Sex[T.male]         -2.298  8.814593e-43  ***
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 19 ddl = 265.90

# %% [markdown]
# > Que pensez-vous du nombre de coefficients obtenus. Sont-ils significatifs ?
# >
# > Quel est l'AIC du modèle ? Comparer le (et donc la vraisemblence) à celui obtenu sans regrouper les données.
# >
# > Etait-ce une idée raisonnable ?

# %% [markdown]
# Afin de réduire le nombre de coefficients, et peut-être d'améliorer les performances du modèle, on va quand même encoder nos variables ordinales `Age_range` et `Pclass` (cela se discute plus) avec des entiers.

# %% [markdown]
# > Si ce n'est pas déjà le cas, encoder chacune des classes d'âge par un entier correspondant à la borne sup (ou inf si vous le souhaitez) de la classe. De même pour les classes. Assurez vous que les types correspondants dans le dataframe soeint bien entiers. `.replace({dictionnaire de corerspondances})` et `.astype(int)`

# %%
pt.Pclass = pt.Pclass.astype('int64')
pt.Age_Range = pt.Age_Range.astype('int64')
pt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Pclass     96 non-null     int64
#  1   Sex        96 non-null     category
#  2   Age_Range  96 non-null     int64
#  3   Survived   96 non-null     float64
#  4   Total      96 non-null     float64
#  5   Died       96 non-null     float64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 4.1 KB

# %% [markdown]
# > Mettre en oeuvre un glm sur ces nouvelles données. Afficher les résultats et comparer les AIC.

# %%
model = smf.glm( 'Survived + Died ~ Pclass + Age_Range + Sex', data=pt, family=sm.families.Binomial())
res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                    coef    std err          z   P>|z|     [0.025     0.975]  \
# Intercept        4.9231      0.474     10.379   0.000      3.993      5.853
# Sex[T.male]     -2.5855      0.187    -13.838   0.000     -2.952     -2.219
# Pclass          -1.2250      0.125     -9.822   0.000     -1.469     -0.981
# Age_Range       -0.0340      0.007     -4.745   0.000     -0.048     -0.020
#
#                   p-value Code
# Intercept    3.081016e-25  ***
# Sex[T.male]  1.495428e-43  ***
# Pclass       9.087793e-23  ***
# Age_Range    2.089135e-06  ***
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 4 ddl = 264.17

# %% [markdown]
# > Afficher les figures de diagnostic, via `glm_residplot`. Cela confirme t-il qu'on peut utiliser ce modèle ?

# %%
glm_residplot(res)

# %% [markdown]
# > Enfin, on va définir un modèle agissant sur les *proportions*. Pour cela, définir une nouvelle colonne `PropSurvived` contenant les rapports Survived/Total, et effectuer la régression binomiale sur cette nouvelle variable. Comment se compare ce résultat aux précédents ?

# %%
pt['PropSurvived'] = pt['Survived']/(pt['Total'])

# %%
model = smf.glm( 'PropSurvived ~ Pclass + Age_Range + Sex', data=pt, family=sm.families.Binomial())
res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                    coef    std err          z   P>|z|     [0.025     0.975]  \
# Intercept        3.3635      0.955      3.523   0.000      1.492      5.235
# Sex[T.male]     -2.2969      0.524     -4.381   0.000     -3.325     -1.269
# Pclass          -0.8980      0.321     -2.802   0.005     -1.526     -0.270
# Age_Range        0.0002      0.011      0.023   0.982     -0.021      0.021
#
#               p-value Code
# Intercept    0.000426  ***
# Sex[T.male]  0.000012  ***
# Pclass       0.005082   **
# Age_Range    0.981969
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 4 ddl = 96.50

# %%
glm_residplot(res)

# %% [markdown]
# ## Crimes sur les campus

# %% [markdown]
# Cet exercice va nous permettre d'aborder la régression de Poisson.
#
# Aux US, les étudiants veulent se sentir en sécurité lorsqu'ils fréquentent un collège ou une université. En réponse à la législation, le ministère américain de l'éducation cherche à fournir des données et à rassurer les étudiants et les parents. Tous les établissements d'enseignement supérieur qui participent aux programmes fédéraux d'aide aux étudiants sont tenus, en vertu de la Jeanne Clery Disclosure of Campus Security Policy and Campus Crime Statistics Act et de la Higher Education Opportunity Act, de recueillir et de communiquer au ministère de l'éducation des données sur les délits commis sur les campus. Ces données sont ensuite mises à la disposition du public sur le site web du Bureau de l'éducation postsecondaire. Nous cherchons à savoir s'il existe des différences régionales en matière de criminalité violente sur les campus, en tenant compte des différences de type d'école.

# %% [markdown]
# Chaque ligne du site c_data.csv contient des informations sur la criminalité provenant d'un établissement d'enseignement supérieur, que ce soit un collège ou une université. Les variables comprennent :
#
#
# - Enrollment = enrollment at the school
# - type = college (C) or university (U)
# - nv = the number of violent crimes for that institution for the given year
# - nvrate = number of violent crimes per 1000 students
# - enroll1000 = enrollment at the school, in thousands
# - region = region of the country (C = Central, MW = Midwest, NE = Northeast, SE = Southeast, SW = Southwest, and W = West)

# %% [markdown]
# ### Lecture et analyse

# %% [markdown]
# >Vous commencerez par charger le fichier de données, `c_data.csv`, afficherez les premières lignes et les infos de type des données. Quelles sont les données quantitatives, catégorielles, ordinales ?

# %%
df = pd.read_csv("c_data.csv")
df.head()
# Out:
#    Enrollment type  nv    nvrate  enroll1000 region
# 0        5590    U  30  5.366726       5.590     SE
# 1         540    C   0  0.000000       0.540     SE
# 2       35747    U  23  0.643411      35.747      W
# 3       28176    C   1  0.035491      28.176      W
# 4       10568    U   1  0.094625      10.568     SW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Enrollment  81 non-null     int64
#  1   type        81 non-null     object
#  2   nv          81 non-null     int64
#  3   nvrate      81 non-null     float64
#  4   enroll1000  81 non-null     float64
#  5   region      81 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 3.9+ KB

# %% [markdown]
# > Considérez la variable `nv`. Quelle devrait être la nature et la distribution de cette variable ? Tracer son histogramme pour vous faire ou confirmer une idée.

# %%
sns.distplot(df.nv, kde=False)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_7208\3072822225.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.nv, kde=False)
# <Axes: xlabel='nv'>

# %% [markdown]
# > Examiner quelles sont les proportions des collèges et universités dans chaque région. Vous devriez pouvoir afficher cela avec pd.crosstab et le paramètre normalize='columns'

# %%
pd.crosstab(index=df.type, columns=df.region, normalize='columns')
# Out:
# region         C   MW        NE   SE   SW    W
# type
# C       0.294118  0.3  0.380952  0.4  0.2  0.5
# U       0.705882  0.7  0.619048  0.6  0.8  0.5

# %% [markdown]
# > Pour poursuivre l'exploration, définir une table affichant les moyennes, écart-type ou variance pour les variables `nv`et `nvrate`. Typiquement, vous pourrez utiliser une table croisée `pivot_table`, avec comme paramètre d'aggrégation `aggfunc=['count', 'mean', 'std']`

# %%
pd.pivot_table(index=['region','type'], values=['nv', 'nvrate'], data=df, aggfunc=['count', 'mean', 'std'])
# Out:
#             count              mean                 std
#                nv nvrate         nv    nvrate        nv    nvrate
# region type
# C      C        5      5   1.600000  0.397952  1.816590  0.527344
#        U       12     12   4.750000  0.221944  5.561638  0.186887
# MW     C        3      3   0.333333  0.016263  0.577350  0.028169
#        U        7      7   8.714286  0.401900  5.559205  0.249148
# NE     C        8      8   6.000000  1.124988  5.732115  1.087244
#        U       13     13   5.923077  0.435927  8.901887  0.620511
# SE     C        6      6   1.500000  0.248799  2.738613  0.357819
#        U        9      9  12.777778  1.233761  9.257129  1.645933
# SW     C        2      2   0.000000  0.000000  0.000000  0.000000
#        U        8      8   6.625000  0.425491  9.318760  0.442505
# W      C        4      4   0.500000  0.068016  0.577350  0.113611
#        U        4      4  12.500000  0.467948  7.549834  0.157057

# %%
sns.set(
    context='paper',
    style='darkgrid',
    palette='deep',
    font='sans-serif',
    font_scale=1,
    color_codes=True,
    rc=None,
)

# %% [markdown]
# Ce tableau montre que les variances sont beaucoup plus élevées que les moyeness dans presque tous les groupes. Nous avons donc des raisons de remettre en question l'hypothèse de régression de Poisson selon laquelle la variabilité est égale à la moyenne. Cela devra éventuellement être pris en compte ensuite

# %% [markdown]
# > Tracer les boxplot de nvrate dans les différentes régions, et en fonction de la nature (type) d'établissement. Vous pouvez utiliser `sns.boxplot`, avec un paramètre `hue` qui serait le type.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='region', y='nvrate', hue='type', data=df)
# Out:
# <Axes: xlabel='region', ylabel='nvrate'>

# %% [markdown]
# > Il y a un outlier dans la région "SE" et un taux de 0 pour les collèges de SW. Il est alors décidé de 1) retirer l'outlier, 2) de fusionner les régions SE et SW en une seule région S. Faites-le ! (vous pourrez utiliser un drop et .replace)

# %%
df.region = df.region.replace('SE', 'S').replace('SW', 'S')
df  = df.drop(df[df.nvrate>5].index)

# %% [markdown]
# > Retracer les boxplots après cette correction.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='region', y='nvrate', hue='type', data=df)
# Out:
# <Axes: xlabel='region', ylabel='nvrate'>

# %% [markdown]
# Si l'on considère λ comme le nombre moyen de crimes violents par an, alors λ / enroll1000 représente le nombre pour 1000 élèves, de sorte que le décompte annuel est comparable entre des écoles de tailles différentes.

# %% [markdown]
# ### Modèle de Poisson

# %% [markdown]
# ####  Notion de  modèle de Poisson et d'offset

# %% [markdown]
# Lorsqu'on a affaire à des problèmes de comptages, on fait souvent appel à une loi de Poisson ; et la moyenne de ces comptes, $\lambda$ est le paramètre d'une loi de Poisson. Cependant, les nombres de violences sont évidemment liées au nombre d'étudiants, et comme les universités et collèges ont un nombre d'étudiants différents, il y a un problème d'échantillonnage statitique. Il faut tenir compte des différences de populations, et par exemple travailler avec des taux. On normalise chaque "catégorie" par le nombre d'étudiants et on obtient des  proportions. Ceci fait apparaître dans le modèle un terme d'`offset`, dont le coefficient est fixé à 1.

# %% [markdown]
# $$\log(\frac{\lambda}{enrollment}) = \beta_0 + \beta_1 type$$
#
# $$\log(\lambda) = \beta_0 + \beta_1 type - \log(enrollment)$$

# %% [markdown]
# #### Régression de Poisson
#
# Mettons donc en oeuvre une régression de Poisson pour prédire le nobre de violences, avec un offset qui corrige pour les effectifs, et en fonction des variables type et region

# %%
model = smf.glm('nv ~ type + region', family = sm.families.Poisson(),
               offset = np.log(df.enroll1000), data = df)

res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                     coef    std err          z   P>|z|     [0.025     0.975]  \
# Intercept        -1.5478      0.171     -9.044   0.000     -1.883     -1.212
# type[T.U]         0.2796      0.133      2.100   0.036      0.019      0.541
# region[T.MW]      0.0991      0.178      0.558   0.577     -0.249      0.447
# region[T.NE]      0.7781      0.153      5.084   0.000      0.478      1.078
# region[T.S]       0.5824      0.149      3.910   0.000      0.290      0.874
# region[T.W]       0.2628      0.188      1.401   0.161     -0.105      0.630
#
#                    p-value Code
# Intercept     1.511819e-19  ***
# type[T.U]     3.575764e-02    *
# region[T.MW]  5.766213e-01
# region[T.NE]  3.702808e-07  ***
# region[T.S]   9.237789e-05  ***
# region[T.W]   1.611722e-01
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 6 ddl = 573.32

# %% [markdown]
# > Écrire ("sur le papier", pas de calculs), quel est le modèle pour le taux de crime, pour la région NE et pour la région centre. Vous devez obtenir un modèle multiplicatif. Que peut on dire sur le rapport entre ces taux ? Quel est, suivant la même démarche, le rapport entre les taux de crime entre universités et collèges.

# %% [markdown]
# Le coefficient estimé à 0,778 signifie que le taux de crimes violents pour 1 000 dans le Nord-Est est près de 2,2 (e^0,778) fois celui de la région centrale en tenant compte du type d'école.
#
# De même, il apparaît que le taux de crimes est plus important de e^0.28 = 1.32 (32%) dans les universités par comparaison aux collèges...

# %% [markdown]
# L'analyse exploratoire suggère que l'effet du type d'institution puise varier suivant les régions. On peut essayer de modéliser cette variation par un terme d'interaction.
#
# > Introduire dans le modèle un terme d'interaction entre type et région. Afficher les résultats. En considérant les p-values, ce terme est-il utile ? le modèle s'est-il amélioré ?

# %%
model = smf.glm('nv ~ type + region + type:region', family = sm.families
                .Poisson(),
               offset = np.log(df.enroll1000), data = df)
res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                               coef    std err          z   P>|z|     [0.025  \
# Intercept                  -1.4741      0.354     -4.169   0.000     -2.167
# type[T.U]                   0.1959      0.378      0.519   0.604     -0.544
# region[T.MW]               -1.9765      1.061     -1.863   0.062     -4.055
# region[T.NE]                1.5529      0.382      4.066   0.000      0.804
# region[T.S]                -0.1562      0.486     -0.322   0.748     -1.109
# region[T.W]                -1.8337      0.791     -2.319   0.020     -3.383
# type[T.U]:region[T.MW]      2.1965      1.077      2.040   0.041      0.086
# type[T.U]:region[T.NE]     -1.0698      0.420     -2.547   0.011     -1.893
# type[T.U]:region[T.S]       0.8121      0.511      1.590   0.112     -0.189
# type[T.U]:region[T.W]       2.4106      0.814      2.962   0.003      0.815
#
#                            0.975]   p-value Code
# Intercept                  -0.781  0.000031  ***
# type[T.U]                   0.936  0.603771
# region[T.MW]                0.102  0.062395    .
# region[T.NE]                2.301  0.000048  ***
# region[T.S]                 0.796  0.747792
# region[T.W]                -0.284  0.020372    *
# type[T.U]:region[T.MW]      4.306  0.041321    *
# type[T.U]:region[T.NE]     -0.247  0.010856    *
# type[T.U]:region[T.S]       1.813  0.111848
# type[T.U]:region[T.W]       4.006  0.003061   **
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 10 ddl = 509.33

# %% [markdown]
# > Tracer les graphes de diagnostic

# %%
glm_residplot(res)

# %% [markdown]
# #### Régression avec une binomiale négative
#
# Cependant deux choses restent ennuyeuses : (a) la déviance reste importante (b) les observations ne semblent pas vraiment Poisson, car la variance devrait être égale à la moyenne et est bien plus importante. Une manière de traiter cela est (éventuellement) d'utiliser un autre modèle statistique et la binomiale négative  est une bon candidat. Rappelons que la binomiale négative apparaît lorsque le paramètre d'une loi de Poisson est lui-même aléatoire et suit une loi Gamma. On a deux niveaux d'aléatoire qui se traduisent par une augmentation de la variance.

# %% [markdown]
# > Mettre en oeuvre ! (la lien canonique est toujours un log ; on pourra donc conserver l'offset). La famille est `sm.families.NegativeBinomial()`

# %%
model = smf.glm('nv ~ type + region+type:region', family = sm.families.NegativeBinomial(alpha=1),
               offset = np.log(df.enroll1000), data = df)

res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                               coef    std err          z   P>|z|     [0.025  \
# Intercept                  -0.9648      0.575     -1.677   0.093     -2.092
# type[T.U]                  -0.4844      0.663     -0.731   0.465     -1.784
# region[T.MW]               -2.5780      1.387     -1.859   0.063     -5.296
# region[T.NE]                1.0917      0.693      1.575   0.115     -0.267
# region[T.S]                -0.6687      0.793     -0.843   0.399     -2.223
# region[T.W]                -2.2223      1.045     -2.127   0.033     -4.270
# type[T.U]:region[T.MW]      3.0983      1.482      2.091   0.037      0.194
# type[T.U]:region[T.NE]     -0.4883      0.828     -0.590   0.555     -2.111
# type[T.U]:region[T.S]       1.5260      0.901      1.693   0.090     -0.240
# type[T.U]:region[T.W]       2.9162      1.214      2.403   0.016      0.538
#
#                            0.975]   p-value Code
# Intercept                   0.163  0.093460    .
# type[T.U]                   0.815  0.465005
# region[T.MW]                0.141  0.063082    .
# region[T.NE]                2.450  0.115271
# region[T.S]                 0.886  0.399216
# region[T.W]                -0.174  0.033455    *
# type[T.U]:region[T.MW]      6.003  0.036551    *
# type[T.U]:region[T.NE]      1.134  0.555326
# type[T.U]:region[T.S]       3.292  0.090408    .
# type[T.U]:region[T.W]       5.295  0.016266    *
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 10 ddl = 410.10

# %%
glm_residplot(res)

# %% [markdown]
# Les graphes de diagnostic ne sont pas sensiblement différents, et il manque de la normalité dans les résidus. L'AIC s'est amélioré ce qui indique que le modèle est mieux adapté. Cependant les résidus reste relativement importants avec des pattern visibles. Il peut y avoir encore du travail. De plus, il est fort possible qu'il y ait d'autres variables explicatives à prendre en compte qui complèteraient utilement les qualques variables présentes. S'il y a de l'info manquante dans les données, on ne peut pas faire de miracle !

# %% [markdown]
# ## Réussite en maths

# %% [markdown]
# Il s'agit d'un autre exercice sur la régression binomiale, que vous pourriez passer dans un premier temps.

# %% [markdown]
# Le jeu de données rapporte des taux de réussite en mathématiques, en fonction de différents paramètres. On est donc dans une situation Succès/échecs modélisés par une loi binomiale.
#
# ### Lecture et analyse
#
# >- Vous lirez les données via `sm.datasets.star98.load_pandas().data`
# >- et vous pourrez consulter la description par `print(sm.datasets.star98.NOTE)`

# %%
print(sm.datasets.star98.NOTE)
# Out:
# ::
#
#     Number of Observations - 303 (counties in California).
#
#     Number of Variables - 13 and 8 interaction terms.
#
#     Definition of variables names::
#
#         NABOVE   - Total number of students above the national median for the
#                    math section.
#         NBELOW   - Total number of students below the national median for the
#                    math section.
#         LOWINC   - Percentage of low income students
#         PERASIAN - Percentage of Asian student
#         PERBLACK - Percentage of black students
#         PERHISP  - Percentage of Hispanic students
#         PERMINTE - Percentage of minority teachers
#         AVYRSEXP - Sum of teachers' years in educational service divided by the
#                 number of teachers.
#         AVSALK   - Total salary budget including benefits divided by the number
#                    of full-time teachers (in thousands)
#         PERSPENK - Per-pupil spending (in thousands)
#         PTRATIO  - Pupil-teacher ratio.
#         PCTAF    - Percentage of students taking UC/CSU prep courses
#         PCTCHRT  - Percentage of charter schools
#         PCTYRRND - Percentage of year-round schools
#
#         The below variables are interaction terms of the variables defined
#         above.
#
#         PERMINTE_AVYRSEXP
#         PEMINTE_AVSAL
#         AVYRSEXP_AVSAL
#         PERSPEN_PTRATIO
#         PERSPEN_PCTAF
#         PTRATIO_PCTAF
#         PERMINTE_AVTRSEXP_AVSAL
#         PERSPEN_PTRATIO_PCTAF

# %%
full_data = sm.datasets.star98.load_pandas().data

# %% [markdown]
# ### Régression
#
# > Mettre en oeuvre une régression binomiale pour `NABOVE + NBELOW` en fonction de l'ensemble des variables (*sans* les termes d'interaction)

# %%
glm_binom2 = smf.glm("NABOVE + NBELOW  ~ LOWINC + PERASIAN + PERBLACK + PERHISP + PCTCHRT + PCTYRRND ", full_data, family=sm.families.Binomial())

res = glm_binom2.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                  coef    std err          z   P>|z|     [0.025     0.975]  \
# Intercept      0.9175      0.012     78.709   0.000      0.895      0.940
# LOWINC        -0.0160      0.000    -42.939   0.000     -0.017     -0.015
# PERASIAN       0.0141      0.000     28.314   0.000      0.013      0.015
# PERBLACK      -0.0158      0.001    -29.428   0.000     -0.017     -0.015
# PERHISP       -0.0122      0.000    -38.284   0.000     -0.013     -0.012
# PCTCHRT        0.0037      0.001      3.117   0.002      0.001      0.006
# PCTYRRND      -0.0035      0.000    -17.554   0.000     -0.004     -0.003
#
#                  p-value Code
# Intercept   0.000000e+00  ***
# LOWINC      0.000000e+00  ***
# PERASIAN   2.347270e-176  ***
# PERBLACK   2.432741e-190  ***
# PERHISP     0.000000e+00  ***
# PCTCHRT     1.824463e-03   **
# PCTYRRND    5.527180e-69  ***
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 7 ddl = 7167.37

# %% [markdown]
# > Mettre en oeuvre une régression binomiale pour `NABOVE + NBELOW` en fonction de l'ensemble des variables  et en ajoutant des termes d'interaction via `PERMINTE*AVYRSEXP*AVSALK + PERSPENK*PTRATIO*PCTAF`
# > Comment évolue l'AIC, les coefficients sont-ils significatifs ?

# %%
glm_binom2 = smf.glm("NABOVE + NBELOW  ~ LOWINC + PERASIAN + PERBLACK + PERHISP + PCTCHRT + \
           PCTYRRND + PERMINTE*AVYRSEXP*AVSALK + PERSPENK*PTRATIO*PCTAF", 
                     full_data, family=sm.families.Binomial())

res = glm_binom2.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                                 coef    std err          z   P>|z|     [0.025  \
# Intercept                     2.9589      1.547      1.913   0.056     -0.073
# LOWINC                       -0.0168      0.000    -38.749   0.000     -0.018
# PERASIAN                      0.0099      0.001     16.505   0.000      0.009
# PERBLACK                     -0.0187      0.001    -25.182   0.000     -0.020
# PERHISP                      -0.0142      0.000    -32.818   0.000     -0.015
# PCTCHRT                       0.0049      0.001      3.921   0.000      0.002
# PCTYRRND                     -0.0036      0.000    -15.878   0.000     -0.004
# PERMINTE                      0.2545      0.030      8.498   0.000      0.196
# AVYRSEXP                      0.2407      0.057      4.212   0.000      0.129
# PERMINTE:AVYRSEXP            -0.0141      0.002     -7.391   0.000     -0.018
# AVSALK                        0.0804      0.014      5.775   0.000      0.053
# PERMINTE:AVSALK              -0.0040      0.000     -8.450   0.000     -0.005
# AVYRSEXP:AVSALK              -0.0039      0.001     -4.059   0.000     -0.006
# PERMINTE:AVYRSEXP:AVSALK      0.0002   2.99e-05      7.428   0.000      0.000
# PERSPENK                     -1.9522      0.317     -6.162   0.000     -2.573
# PTRATIO                      -0.3341      0.061     -5.453   0.000     -0.454
# PERSPENK:PTRATIO              0.0917      0.015      6.321   0.000      0.063
# PCTAF                        -0.1690      0.033     -5.169   0.000     -0.233
# PERSPENK:PCTAF                0.0490      0.007      6.574   0.000      0.034
# PTRATIO:PCTAF                 0.0080      0.001      5.362   0.000      0.005
# PERSPENK:PTRATIO:PCTAF       -0.0022      0.000     -6.445   0.000     -0.003
#
#                              0.975]        p-value Code
# Intercept                     5.990   5.574577e-02    .
# LOWINC                       -0.016   0.000000e+00  ***
# PERASIAN                      0.011   3.392690e-61  ***
# PERBLACK                     -0.017  6.276757e-140  ***
# PERHISP                      -0.013  3.269482e-236  ***
# PCTCHRT                       0.007   8.810637e-05  ***
# PCTYRRND                     -0.003   8.962276e-57  ***
# PERMINTE                      0.313   1.924040e-17  ***
# AVYRSEXP                      0.353   2.525627e-05  ***
# PERMINTE:AVYRSEXP            -0.010   1.457877e-13  ***
# AVSALK                        0.108   7.694523e-09  ***
# PERMINTE:AVSALK              -0.003   2.921526e-17  ***
# AVYRSEXP:AVSALK              -0.002   4.924508e-05  ***
# PERMINTE:AVYRSEXP:AVSALK      0.000   1.101839e-13  ***
# PERSPENK                     -1.331   7.186438e-10  ***
# PTRATIO                      -0.214   4.946236e-08  ***
# PERSPENK:PTRATIO              0.120   2.596818e-10  ***
# PCTAF                        -0.105   2.357777e-07  ***
# PERSPENK:PCTAF                0.064   4.886509e-11  ***
# PTRATIO:PCTAF                 0.011   8.217090e-08  ***
# PERSPENK:PTRATIO:PCTAF       -0.002   1.154916e-10  ***
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 21 ddl = 6039.22

# %% [markdown]
# Le modèle étant obtenu, comparons sa capacité de prédiction des proportions et les proportions de succès effectives dans les données. Pour ce faire,
#
# > - Calculer  les prédictions, en utilisant `res.predict`
# > - Calculer les proportions effectives dans les données
#
# Comparer ces deux quantités, par exemple en traçant l'une en fonction de l'autre.

# %%
idx = full_data.index
Res = pd.DataFrame(index=idx, columns=['pred', 'prop'])
for m in idx:
    Res.loc[idx,'pred'] = res.predict(full_data.loc[idx])
    Res.loc[idx,'prop'] = full_data.loc[idx,'NABOVE']/(full_data.loc[idx,'NABOVE'] + full_data.loc[idx,'NBELOW'])

# %%
Res['pred'] = Res['pred'].astype('float64')
Res['prop'] = Res['prop'].astype('float64')

sns.lmplot(x='pred', y='prop', data=Res)

# %% [markdown]
# > Si on persiste à augmenter le nombre de termes, via des interactions, en ajoutant `PERASIAN*PERBLACK*PERHISP*PCTCHRT*PCTYRRND`, que devbient l'AIC et la signification des variables ,

# %%
glm_binom2 = smf.glm("NABOVE + NBELOW  ~ LOWINC + PERASIAN + PERBLACK + PERHISP + PCTCHRT + \
           PCTYRRND + PERMINTE*AVYRSEXP*AVSALK + PERSPENK*PTRATIO*PCTAF + \
           PERASIAN*PERBLACK*PERHISP*PCTCHRT*PCTYRRND ", 
                     full_data, family=sm.families.Binomial())

res = glm_binom2.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                                                   coef    std err          z  \
# Intercept                                       7.8386      1.695      4.625
# LOWINC                                         -0.0182      0.001    -34.137
# PERASIAN                                        0.0200      0.002     10.273
# PERBLACK                                       -0.0121      0.004     -3.323
# PERHISP                                        -0.0134      0.001    -22.571
# PCTCHRT                                        -0.0421      0.009     -4.850
# PCTYRRND                                       -0.0042      0.001     -5.759
# PERMINTE                                        0.1618      0.039      4.147
# AVYRSEXP                                       -0.0417      0.066     -0.632
# PERMINTE:AVYRSEXP                              -0.0073      0.003     -2.856
# AVSALK                                          0.0084      0.016      0.521
# PERMINTE:AVSALK                                -0.0026      0.001     -4.261
# AVYRSEXP:AVSALK                                 0.0009      0.001      0.805
# PERMINTE:AVYRSEXP:AVSALK                        0.0001      4e-05      2.979
# PERSPENK                                       -2.3619      0.334     -7.074
# PTRATIO                                        -0.3615      0.065     -5.570
# PERSPENK:PTRATIO                                0.1099      0.015      7.183
# PCTAF                                          -0.1944      0.035     -5.546
# PERSPENK:PCTAF                                  0.0605      0.008      7.566
# PTRATIO:PCTAF                                   0.0093      0.002      5.810
# PERSPENK:PTRATIO:PCTAF                         -0.0028      0.000     -7.499
# PERASIAN:PERBLACK                              -0.0014      0.000     -3.622
# PERASIAN:PERHISP                               -0.0002   5.68e-05     -4.129
# PERBLACK:PERHISP                             -7.98e-05   8.18e-05     -0.975
# PERASIAN:PERBLACK:PERHISP                    2.397e-05   1.15e-05      2.080
# PERASIAN:PCTCHRT                                0.0307      0.006      5.160
# PERBLACK:PCTCHRT                               -0.0055      0.002     -2.425
# PERASIAN:PERBLACK:PCTCHRT                      -0.0008      0.001     -1.388
# PERHISP:PCTCHRT                                 0.0011      0.000      3.898
# PERASIAN:PERHISP:PCTCHRT                       -0.0006      0.000     -4.305
# PERBLACK:PERHISP:PCTCHRT                        0.0002   9.11e-05      1.867
# PERASIAN:PERBLACK:PERHISP:PCTCHRT           -1.028e-06   2.21e-05     -0.046
# PERASIAN:PCTYRRND                              -0.0004      0.000     -3.368
# PERBLACK:PCTYRRND                              -0.0002   9.92e-05     -2.195
# PERASIAN:PERBLACK:PCTYRRND                   3.922e-05    1.5e-05      2.609
# PERHISP:PCTYRRND                            -2.203e-05   1.97e-05     -1.121
# PERASIAN:PERHISP:PCTYRRND                    1.521e-05   4.28e-06      3.554
# PERBLACK:PERHISP:PCTYRRND                     5.96e-06   2.13e-06      2.799
# PERASIAN:PERBLACK:PERHISP:PCTYRRND          -1.281e-06   4.86e-07     -2.634
# PCTCHRT:PCTYRRND                                0.0010      0.001      1.578
# PERASIAN:PCTCHRT:PCTYRRND                      -0.0008      0.000     -2.331
# PERBLACK:PCTCHRT:PCTYRRND                    8.942e-05      0.000      0.835
# PERASIAN:PERBLACK:PCTCHRT:PCTYRRND           6.844e-05   3.76e-05      1.821
# PERHISP:PCTCHRT:PCTYRRND                      4.56e-05   1.96e-05      2.327
# PERASIAN:PERHISP:PCTCHRT:PCTYRRND            2.794e-06   8.48e-06      0.329
# PERBLACK:PERHISP:PCTCHRT:PCTYRRND           -1.068e-05   4.74e-06     -2.252
# PERASIAN:PERBLACK:PERHISP:PCTCHRT:PCTYRRND   8.069e-07   1.25e-06      0.644
#
#                                              P>|z|     [0.025     0.975]  \
# Intercept                                    0.000      4.516     11.161
# LOWINC                                       0.000     -0.019     -0.017
# PERASIAN                                     0.000      0.016      0.024
# PERBLACK                                     0.001     -0.019     -0.005
# PERHISP                                      0.000     -0.015     -0.012
# PCTCHRT                                      0.000     -0.059     -0.025
# PCTYRRND                                     0.000     -0.006     -0.003
# PERMINTE                                     0.000      0.085      0.238
# AVYRSEXP                                     0.528     -0.171      0.088
# PERMINTE:AVYRSEXP                            0.004     -0.012     -0.002
# AVSALK                                       0.602     -0.023      0.040
# PERMINTE:AVSALK                              0.000     -0.004     -0.001
# AVYRSEXP:AVSALK                              0.421     -0.001      0.003
# PERMINTE:AVYRSEXP:AVSALK                     0.003   4.07e-05      0.000
# PERSPENK                                     0.000     -3.016     -1.707
# PTRATIO                                      0.000     -0.489     -0.234
# PERSPENK:PTRATIO                             0.000      0.080      0.140
# PCTAF                                        0.000     -0.263     -0.126
# PERSPENK:PCTAF                               0.000      0.045      0.076
# PTRATIO:PCTAF                                0.000      0.006      0.012
# PERSPENK:PTRATIO:PCTAF                       0.000     -0.004     -0.002
# PERASIAN:PERBLACK                            0.000     -0.002     -0.001
# PERASIAN:PERHISP                             0.000     -0.000     -0.000
# PERBLACK:PERHISP                             0.330     -0.000   8.06e-05
# PERASIAN:PERBLACK:PERHISP                    0.038   1.38e-06   4.66e-05
# PERASIAN:PCTCHRT                             0.000      0.019      0.042
# PERBLACK:PCTCHRT                             0.015     -0.010     -0.001
# PERASIAN:PERBLACK:PCTCHRT                    0.165     -0.002      0.000
# PERHISP:PCTCHRT                              0.000      0.001      0.002
# PERASIAN:PERHISP:PCTCHRT                     0.000     -0.001     -0.000
# PERBLACK:PERHISP:PCTCHRT                     0.062  -8.44e-06      0.000
# PERASIAN:PERBLACK:PERHISP:PCTCHRT            0.963  -4.44e-05   4.24e-05
# PERASIAN:PCTYRRND                            0.001     -0.001     -0.000
# PERBLACK:PCTYRRND                            0.028     -0.000  -2.34e-05
# PERASIAN:PERBLACK:PCTYRRND                   0.009   9.76e-06   6.87e-05
# PERHISP:PCTYRRND                             0.262  -6.05e-05   1.65e-05
# PERASIAN:PERHISP:PCTYRRND                    0.000   6.82e-06   2.36e-05
# PERBLACK:PERHISP:PCTYRRND                    0.005   1.79e-06   1.01e-05
# PERASIAN:PERBLACK:PERHISP:PCTYRRND           0.008  -2.23e-06  -3.28e-07
# PCTCHRT:PCTYRRND                             0.115     -0.000      0.002
# PERASIAN:PCTCHRT:PCTYRRND                    0.020     -0.001     -0.000
# PERBLACK:PCTCHRT:PCTYRRND                    0.404     -0.000      0.000
# PERASIAN:PERBLACK:PCTCHRT:PCTYRRND           0.069  -5.22e-06      0.000
# PERHISP:PCTCHRT:PCTYRRND                     0.020   7.19e-06    8.4e-05
# PERASIAN:PERHISP:PCTCHRT:PCTYRRND            0.742  -1.38e-05   1.94e-05
# PERBLACK:PERHISP:PCTCHRT:PCTYRRND            0.024     -2e-05  -1.38e-06
# PERASIAN:PERBLACK:PERHISP:PCTCHRT:PCTYRRND   0.519  -1.65e-06   3.26e-06
#
#                                                   p-value Code
# Intercept                                    3.754840e-06  ***
# LOWINC                                      2.109807e-255  ***
# PERASIAN                                     9.360368e-25  ***
# PERBLACK                                     8.891282e-04  ***
# PERHISP                                     8.432865e-113  ***
# PCTCHRT                                      1.233064e-06  ***
# PCTYRRND                                     8.478091e-09  ***
# PERMINTE                                     3.368802e-05  ***
# AVYRSEXP                                     5.276128e-01
# PERMINTE:AVYRSEXP                            4.293364e-03   **
# AVSALK                                       6.022773e-01
# PERMINTE:AVSALK                              2.034086e-05  ***
# AVYRSEXP:AVSALK                              4.210376e-01
# PERMINTE:AVYRSEXP:AVSALK                     2.888796e-03   **
# PERSPENK                                     1.510333e-12  ***
# PTRATIO                                      2.547704e-08  ***
# PERSPENK:PTRATIO                             6.837711e-13  ***
# PCTAF                                        2.922727e-08  ***
# PERSPENK:PCTAF                               3.853206e-14  ***
# PTRATIO:PCTAF                                6.240925e-09  ***
# PERSPENK:PTRATIO:PCTAF                       6.439317e-14  ***
# PERASIAN:PERBLACK                            2.927576e-04  ***
# PERASIAN:PERHISP                             3.646649e-05  ***
# PERBLACK:PERHISP                             3.295545e-01
# PERASIAN:PERBLACK:PERHISP                    3.751297e-02    *
# PERASIAN:PCTCHRT                             2.464801e-07  ***
# PERBLACK:PCTCHRT                             1.531534e-02    *
# PERASIAN:PERBLACK:PCTCHRT                    1.652369e-01
# PERHISP:PCTCHRT                              9.698893e-05  ***
# PERASIAN:PERHISP:PCTCHRT                     1.666595e-05  ***
# PERBLACK:PERHISP:PCTCHRT                     6.184588e-02    .
# PERASIAN:PERBLACK:PERHISP:PCTCHRT            9.629785e-01
# PERASIAN:PCTYRRND                            7.567111e-04  ***
# PERBLACK:PCTYRRND                            2.813172e-02    *
# PERASIAN:PERBLACK:PCTYRRND                   9.073475e-03   **
# PERHISP:PCTYRRND                             2.622926e-01
# PERASIAN:PERHISP:PCTYRRND                    3.789638e-04  ***
# PERBLACK:PERHISP:PCTYRRND                    5.118465e-03   **
# PERASIAN:PERBLACK:PERHISP:PCTYRRND           8.428591e-03   **
# PCTCHRT:PCTYRRND                             1.146317e-01
# PERASIAN:PCTCHRT:PCTYRRND                    1.976017e-02    *
# PERBLACK:PCTCHRT:PCTYRRND                    4.039092e-01
# PERASIAN:PERBLACK:PCTCHRT:PCTYRRND           6.857849e-02    .
# PERHISP:PCTCHRT:PCTYRRND                     1.996720e-02    *
# PERASIAN:PERHISP:PCTCHRT:PCTYRRND            7.417804e-01
# PERBLACK:PERHISP:PCTCHRT:PCTYRRND            2.432587e-02    *
# PERASIAN:PERBLACK:PERHISP:PCTCHRT:PCTYRRND   5.194043e-01
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 47 ddl = 5322.57

# %% [markdown]
# > Retirer quelques variables non significatives et réitérez. Evolution de l'AIC ?

# %%
glm_binom2 = smf.glm("NABOVE + NBELOW  ~ LOWINC + PERASIAN + PERBLACK + PERHISP + PCTCHRT + \
           PCTYRRND + PERMINTE*AVYRSEXP*AVSALK + PERSPENK*PTRATIO*PCTAF + \
           PERASIAN*PERBLACK*PERHISP*PCTCHRT*PCTYRRND - AVYRSEXP - PERBLACK:PERHISP - PERHISP:PCTYRRND", 
                     full_data, family=sm.families.Binomial())

res = glm_binom2.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                                                   coef    std err          z  \
# Intercept                                       7.2665      1.438      5.054
# LOWINC                                         -0.0183      0.001    -35.893
# PERASIAN                                        0.0187      0.002     11.125
# PERBLACK                                       -0.0155      0.001    -10.605
# PERHISP                                        -0.0136      0.001    -25.743
# PCTCHRT                                        -0.0414      0.009     -4.871
# PCTYRRND                                       -0.0050      0.000    -11.582
# PERMINTE                                        0.1766      0.026      6.672
# PERMINTE:AVYRSEXP                              -0.0084      0.002     -5.144
# AVSALK                                          0.0182      0.003      5.537
# PERMINTE:AVSALK                                -0.0029      0.000     -7.228
# AVYRSEXP:AVSALK                                 0.0002      0.000      1.679
# PERMINTE:AVYRSEXP:AVSALK                        0.0001   2.35e-05      5.853
# PERSPENK                                       -2.3547      0.334     -7.058
# PTRATIO                                        -0.3609      0.065     -5.567
# PERSPENK:PTRATIO                                0.1097      0.015      7.167
# PCTAF                                          -0.1934      0.035     -5.554
# PERSPENK:PCTAF                                  0.0601      0.008      7.552
# PTRATIO:PCTAF                                   0.0093      0.002      5.805
# PERSPENK:PTRATIO:PCTAF                         -0.0028      0.000     -7.478
# PERASIAN:PERBLACK                              -0.0011      0.000     -4.358
# PERASIAN:PERHISP                               -0.0002   5.03e-05     -3.901
# PERASIAN:PERBLACK:PERHISP                    1.625e-05   9.02e-06      1.802
# PERASIAN:PCTCHRT                                0.0298      0.006      5.084
# PERBLACK:PCTCHRT                               -0.0054      0.002     -2.424
# PERASIAN:PERBLACK:PCTCHRT                      -0.0008      0.001     -1.391
# PERHISP:PCTCHRT                                 0.0011      0.000      3.839
# PERASIAN:PERHISP:PCTCHRT                       -0.0006      0.000     -4.216
# PERBLACK:PERHISP:PCTCHRT                        0.0002   8.98e-05      1.938
# PERASIAN:PERBLACK:PERHISP:PCTCHRT           -1.684e-06   2.19e-05     -0.077
# PERASIAN:PCTYRRND                              -0.0003   8.05e-05     -3.444
# PERBLACK:PCTYRRND                              -0.0001   6.38e-05     -1.804
# PERASIAN:PERBLACK:PCTYRRND                   2.807e-05   1.26e-05      2.236
# PERASIAN:PERHISP:PCTYRRND                     1.19e-05   2.83e-06      4.203
# PERBLACK:PERHISP:PCTYRRND                    3.426e-06   1.13e-06      3.033
# PERASIAN:PERBLACK:PERHISP:PCTYRRND          -9.219e-07   4.07e-07     -2.265
# PCTCHRT:PCTYRRND                                0.0010      0.001      1.553
# PERASIAN:PCTCHRT:PCTYRRND                      -0.0007      0.000     -2.272
# PERBLACK:PCTCHRT:PCTYRRND                    9.899e-05      0.000      0.942
# PERASIAN:PERBLACK:PCTCHRT:PCTYRRND           6.675e-05   3.72e-05      1.797
# PERHISP:PCTCHRT:PCTYRRND                     4.678e-05   1.93e-05      2.425
# PERASIAN:PERHISP:PCTCHRT:PCTYRRND            2.299e-06   8.41e-06      0.273
# PERBLACK:PERHISP:PCTCHRT:PCTYRRND           -1.129e-05   4.68e-06     -2.412
# PERASIAN:PERBLACK:PERHISP:PCTCHRT:PCTYRRND   8.555e-07   1.24e-06      0.687
#
#                                              P>|z|     [0.025     0.975]  \
# Intercept                                    0.000      4.448     10.084
# LOWINC                                       0.000     -0.019     -0.017
# PERASIAN                                     0.000      0.015      0.022
# PERBLACK                                     0.000     -0.018     -0.013
# PERHISP                                      0.000     -0.015     -0.013
# PCTCHRT                                      0.000     -0.058     -0.025
# PCTYRRND                                     0.000     -0.006     -0.004
# PERMINTE                                     0.000      0.125      0.228
# PERMINTE:AVYRSEXP                            0.000     -0.012     -0.005
# AVSALK                                       0.000      0.012      0.025
# PERMINTE:AVSALK                              0.000     -0.004     -0.002
# AVYRSEXP:AVSALK                              0.093  -3.13e-05      0.000
# PERMINTE:AVYRSEXP:AVSALK                     0.000   9.15e-05      0.000
# PERSPENK                                     0.000     -3.009     -1.701
# PTRATIO                                      0.000     -0.488     -0.234
# PERSPENK:PTRATIO                             0.000      0.080      0.140
# PCTAF                                        0.000     -0.262     -0.125
# PERSPENK:PCTAF                               0.000      0.045      0.076
# PTRATIO:PCTAF                                0.000      0.006      0.012
# PERSPENK:PTRATIO:PCTAF                       0.000     -0.004     -0.002
# PERASIAN:PERBLACK                            0.000     -0.002     -0.001
# PERASIAN:PERHISP                             0.000     -0.000  -9.77e-05
# PERASIAN:PERBLACK:PERHISP                    0.072  -1.42e-06   3.39e-05
# PERASIAN:PCTCHRT                             0.000      0.018      0.041
# PERBLACK:PCTCHRT                             0.015     -0.010     -0.001
# PERASIAN:PERBLACK:PCTCHRT                    0.164     -0.002      0.000
# PERHISP:PCTCHRT                              0.000      0.001      0.002
# PERASIAN:PERHISP:PCTCHRT                     0.000     -0.001     -0.000
# PERBLACK:PERHISP:PCTCHRT                     0.053  -2.01e-06      0.000
# PERASIAN:PERBLACK:PERHISP:PCTCHRT            0.939  -4.46e-05   4.12e-05
# PERASIAN:PCTYRRND                            0.001     -0.000     -0.000
# PERBLACK:PCTYRRND                            0.071     -0.000   9.96e-06
# PERASIAN:PERBLACK:PCTYRRND                   0.025   3.46e-06   5.27e-05
# PERASIAN:PERHISP:PCTYRRND                    0.000   6.35e-06   1.75e-05
# PERBLACK:PERHISP:PCTYRRND                    0.002   1.21e-06   5.64e-06
# PERASIAN:PERBLACK:PERHISP:PCTYRRND           0.023  -1.72e-06  -1.24e-07
# PCTCHRT:PCTYRRND                             0.120     -0.000      0.002
# PERASIAN:PCTCHRT:PCTYRRND                    0.023     -0.001     -0.000
# PERBLACK:PCTCHRT:PCTYRRND                    0.346     -0.000      0.000
# PERASIAN:PERBLACK:PCTCHRT:PCTYRRND           0.072  -6.07e-06      0.000
# PERHISP:PCTCHRT:PCTYRRND                     0.015   8.96e-06   8.46e-05
# PERASIAN:PERHISP:PCTCHRT:PCTYRRND            0.785  -1.42e-05   1.88e-05
# PERBLACK:PERHISP:PCTCHRT:PCTYRRND            0.016  -2.05e-05  -2.12e-06
# PERASIAN:PERBLACK:PERHISP:PCTCHRT:PCTYRRND   0.492  -1.58e-06    3.3e-06
#
#                                                   p-value Code
# Intercept                                    4.328062e-07  ***
# LOWINC                                      3.976776e-282  ***
# PERASIAN                                     9.471297e-29  ***
# PERBLACK                                     2.818041e-26  ***
# PERHISP                                     3.887374e-146  ***
# PCTCHRT                                      1.110449e-06  ***
# PCTYRRND                                     5.110086e-31  ***
# PERMINTE                                     2.524400e-11  ***
# PERMINTE:AVYRSEXP                            2.687505e-07  ***
# AVSALK                                       3.078271e-08  ***
# PERMINTE:AVSALK                              4.912272e-13  ***
# AVYRSEXP:AVSALK                              9.324215e-02    .
# PERMINTE:AVYRSEXP:AVSALK                     4.825989e-09  ***
# PERSPENK                                     1.687515e-12  ***
# PTRATIO                                      2.585667e-08  ***
# PERSPENK:PTRATIO                             7.664334e-13  ***
# PCTAF                                        2.784374e-08  ***
# PERSPENK:PCTAF                               4.291922e-14  ***
# PTRATIO:PCTAF                                6.455693e-09  ***
# PERSPENK:PTRATIO:PCTAF                       7.541028e-14  ***
# PERASIAN:PERBLACK                            1.315319e-05  ***
# PERASIAN:PERHISP                             9.574613e-05  ***
# PERASIAN:PERBLACK:PERHISP                    7.154472e-02    .
# PERASIAN:PCTCHRT                             3.703732e-07  ***
# PERBLACK:PCTCHRT                             1.534939e-02    *
# PERASIAN:PERBLACK:PCTCHRT                    1.643443e-01
# PERHISP:PCTCHRT                              1.235424e-04  ***
# PERASIAN:PERHISP:PCTCHRT                     2.489364e-05  ***
# PERBLACK:PERHISP:PCTCHRT                     5.267159e-02    .
# PERASIAN:PERBLACK:PERHISP:PCTCHRT            9.386639e-01
# PERASIAN:PCTYRRND                            5.726285e-04  ***
# PERBLACK:PCTYRRND                            7.124839e-02    .
# PERASIAN:PERBLACK:PCTYRRND                   2.535509e-02    *
# PERASIAN:PERHISP:PCTYRRND                    2.638223e-05  ***
# PERBLACK:PERHISP:PCTYRRND                    2.417642e-03   **
# PERASIAN:PERBLACK:PERHISP:PCTYRRND           2.348812e-02    *
# PCTCHRT:PCTYRRND                             1.204493e-01
# PERASIAN:PCTCHRT:PCTYRRND                    2.311266e-02    *
# PERBLACK:PCTCHRT:PCTYRRND                    3.462036e-01
# PERASIAN:PERBLACK:PCTCHRT:PCTYRRND           7.240279e-02    .
# PERHISP:PCTCHRT:PCTYRRND                     1.532870e-02    *
# PERASIAN:PERHISP:PCTCHRT:PCTYRRND            7.846724e-01
# PERBLACK:PERHISP:PCTCHRT:PCTYRRND            1.585878e-02    *
# PERASIAN:PERBLACK:PERHISP:PCTCHRT:PCTYRRND   4.919644e-01
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 44 ddl = 5318.78

# %% [markdown]
# On peut améliorer légèrement le modèle. Ceci dit ce n'est pas forcément raisonnable au niveau de la généralisation. Il faudrait voir comment évoluent les résultats sur une base de test.

# %% [markdown]
# ## Richesse écologique
#
# On traite à nouveau un problème de comptage, avec une régression de Poisson.
#
# Les données de cet exercice ont été recueillies au cours d'une expérience qui a permis d'étudier la relation entre le nombre d'espèces végétales et la biomasse végétale cultivée dans des parcelles ayant subi trois traitements à pH contrôlé : faible, moyen et élevé. La recherche vise à déterminer si l'augmentation de la biomasse a un effet sur la richesse des espèces et si cet effet peut être modulé par le pH. Par conséquent, l'espèce est la variable de réponse et le pH et la biomasse sont des variables explicatives. Comme le nombre d'espèces est un compte (positif et entier), nous tenterons d'ajuster une distribution de Poisson à ces données.

# %% [markdown]
# ### Lecture et analyse
# >Charger le fichier `species.txt` et procéder à une exploration préliminaire. Combien de variables, de données, dépendances, histogrammes, boxplot...

# %%
species = pd.read_csv("species.txt", sep="\t")

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   pH       90 non-null     object
#  1   Biomass  90 non-null     float64
#  2   Species  90 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
species.describe()
# Out:
#          Biomass    Species
# count  90.000000  90.000000
# mean    3.557008  19.455556
# std     2.587217   9.679309
# min     0.050175   2.000000
# 25%     1.441323  12.250000
# 50%     3.108363  18.500000
# 75%     5.085697  25.750000
# max     9.981770  44.000000

# %% [markdown]
# #### Tracés
#
# displot, boxplot, pairplot (il faudra réencoder pH en 'pH_encoded' sur 3 niveaux -- par exemple 0, 1, 2),

# %%
sns.displot(species.Species, kde=True)

# %%
sns.boxplot(x='pH', y='Species', data=species)
# Out:
# <Axes: xlabel='pH', ylabel='Species'>

# %%
gr = species.pH.replace({"low":0, "mid":1, "high":2})
species['pH_encoded'] = gr

sns.pairplot(species[['Species', 'Biomass', 'pH_encoded']])

# %%
sns.pairplot(species[['Species', 'Biomass', 'pH_encoded', 'pH']], hue='pH')

# %% [markdown]
# #### Tests statistiques
#
# Une fois n'est pas coutume, on va effectuer un test statistque pour tester si nos différents groupes de pH sont significatifs, et doivent donc être pris en compte en tant que variables explicatives distinctes. Pour cela, on va utiliser un ttest et une anova.

# %% [markdown]
# > Vous mettrez en oeuvre un ttest à partir de `sm.stats.ttest_ind(..)`
# > Une anova à partie de `oneway` provenant de  `import statsmodels.stats.oneway as oneway`

# %%
low = species['pH']=='low'
mid = species['pH']=='mid'
high = species['pH']=='high'

# %%
import statsmodels.stats.oneway as oneway

# %%
sm.stats.ttest_ind(species[low]['Species'], species[mid]['Species'])
# Out:
# (-5.377944058409623, 1.4073917745612187e-06, 58.0)

# %%
oneway.anova_oneway(data=(species[low]['Species'], species[mid]['Species'], species[high]['Species']))
# Out:
# <class 'statsmodels.stats.base.HolderTuple'>
# statistic = 33.411646422672135
# pvalue = 3.0423469836301514e-10
# df = (2.0, 55.35946316648363)
# df_num = 2.0
# df_denom = 55.35946316648363
# nobs_t = 90.0
# n_groups = 3
# means = array([11.56666667, 20.        , 26.8       ])
# nobs = array([30., 30., 30.])
# vars_ = array([28.66781609, 45.10344828, 93.26896552])
# use_var = 'unequal'
# welch_correction = True
# tuple = (33.411646422672135, 3.0423469836301514e-10)

# %%
species['logSpecies'] = np.log(species['Species'])

# %% [markdown]
# ### Premier modèle.
#
# Les données sont donc des comptages et l'hypothèse comme quoi la réponse serait Poisson n'est pas déraisonnable. On envisage donc une régression de Poisson, avec un glm utilisant la famille de Poisson (et par défaut un lien en log).
#
# >Effectuez la régression de Species en fonction de Biomass : définissez le modèle, apprenez le (méthode.fit) et affichez le résumé (attribut summary).

# %%
model = smf.glm('Species ~ Biomass', family = sm.families.Poisson(), data = species)
res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                  coef    std err          z   P>|z|     [0.025     0.975]  \
# Intercept      3.1841      0.039     81.311   0.000      3.107      3.261
# Biomass       -0.0644      0.010     -6.550   0.000     -0.084     -0.045
#
#                 p-value Code
# Intercept  0.000000e+00  ***
# Biomass    5.739736e-11  ***
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 2 ddl = 830.86

# %%
print("AIC=", res.aic)
# Out:
# AIC= 830.8629455735812

# %% [markdown]
# > Selon ce modèle, quelle serait la valeur prédite (calcul "à la main") sur le log(mu) lorsque la biomasse = 5 ? Qu'est-ce que cela deviendrait sur l'échelle de la réponse, c'est-à-dire le nombre d'espèces ?

# %%
logmu = 3.1841 -0.0644*5
print("logmu", logmu)
print("mu", np.exp(logmu))
print("Soit 17 espèces")
# Out:
# logmu 2.8621
# mu 17.498234672779724
# Soit 17 espèces

# %%
newdata = pd.DataFrame(data=[5], columns=['Biomass'])
res.predict(newdata)
# Out:
# 0    17.494579
# dtype: float64

# %%
w = res.get_prediction(newdata)
w.summary_frame()
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper
# 0  17.494579  0.525166      16.494967      18.554769

# %% [markdown]
# ### 2e modèle
#
# > Ajouter maintenant la variable explicative `pH`, et éventuellement un terme d'interaction. Comment évolue le modèle ?

# %%
model = smf.glm('Species ~ Biomass * pH', family = sm.families.Poisson(), data
= species)
res = model.fit()
GLMsummary(res)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>
#                          coef    std err          z   P>|z|     [0.025  \
# Intercept              3.7681      0.062     61.240   0.000      3.648
# pH[T.low]             -0.8156      0.103     -7.931   0.000     -1.017
# pH[T.mid]             -0.3315      0.092     -3.596   0.000     -0.512
# Biomass               -0.1071      0.012     -8.577   0.000     -0.132
# Biomass:pH[T.low]     -0.1550      0.040     -3.873   0.000     -0.233
# Biomass:pH[T.mid]     -0.0319      0.023     -1.382   0.167     -0.077
#
#                       0.975]       p-value Code
# Intercept              3.889  0.000000e+00  ***
# pH[T.low]             -0.614  2.178510e-15  ***
# pH[T.mid]             -0.151  3.227966e-04  ***
# Biomass               -0.083  9.719621e-18  ***
# Biomass:pH[T.low]     -0.077  1.076745e-04  ***
# Biomass:pH[T.mid]      0.013  1.669540e-01
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# AIC with 6 ddl = 514.39

# %% [markdown]
# ### diagnostic
#
# #### Tracez les quelques figures de diagnostic

# %% [markdown]
# En utilisant le fonction `glm_residplot(res)`

# %%
glm_residplot(res)

# %% [markdown]
# #### Exploitation des prédictions
#
# > Utilisez `predict()` ou `get_prediction().summary_frame()` pour obtenir les prédictions. Tracez la relation entre le nombre d'espèces et la biomasse pour chaque niveau de pH, ainsi que les données de départ. Pourquoi les courbes ne sont-elles pas des lignes ?

# %%
preds = res.get_prediction().summary_frame()
preds
# Out:
#          mean   mean_se  mean_ci_lower  mean_ci_upper
# 0   41.175684  2.339889      36.835759      46.026931
# 1   35.970380  1.637874      32.899283      39.328158
# 2   34.613579  1.482824      31.825965      37.645359
# 3   28.433125  1.003535      26.532722      30.469644
# 4   27.121046  0.962992      25.297794      29.075702
# ..        ...       ...            ...            ...
# 85  10.410163  0.620736       9.261945      11.700728
# 86   8.733832  0.649283       7.549627      10.103786
# 87   7.575999  0.680767       6.352613       9.034986
# 88   6.100393  0.711208       4.854241       7.666448
# 89   5.342587  0.715691       4.108894       6.946694
#
# [90 rows x 4 columns]

# %%
preds['pH'] = species['pH']
preds['Biomass'] = species['Biomass']
preds['Species'] = species['Species']

# %%
sns.lineplot(x='Biomass',y='mean',hue='pH', data=preds)
# Out:
# <Axes: xlabel='Biomass', ylabel='mean'>

# %%
# Tracé des prédictions
sns.lineplot(x='Biomass',y='mean',hue='pH', data=preds)
# Tracé du scatterplot
#sns.scatterplot(x='Biomass',y='mean',hue='pH', data=preds)
# En principe c'est la ligne ci-dessus, mais elle plante sans explication claire. On le fait à la main
for pH in ['high', 'mid', 'low']:
    data = species[species['pH']==pH]
    sns.scatterplot(x='Biomass',y='Species', data=data)

# %% [markdown]
# > Dans la  mesure où nous disposons dans le `summary_frame` des intervalles de confiance, autant l'utiliser... Ajouter un intervalle de confiance à vos tracés..

# %%
# Tracé des prédictions
sns.lineplot(x='Biomass',y='mean',hue='pH', data=preds)
# Tracé du scatterplot
#sns.scatterplot(x='Biomass',y='mean',hue='pH', data=preds)
# En principe c'est la ligne ci-dessus, mais elle plante sans explication claire. On le fait à la main
for pH in ['high', 'mid', 'low']:
    data = species[species['pH']==pH]
    sns.scatterplot(x='Biomass',y='Species', data=data)
    
plt.gca().set_prop_cycle(None) # reset du color cycle    

for pH in ['high', 'mid', 'low']:
    data = preds[preds['pH']==pH].sort_values(by='Biomass')
    plt.fill_between(data.Biomass, data.mean_ci_lower, data.mean_ci_upper, alpha=.3)

# %% [markdown]
# ## Quine Data
#
# La description des données est ici
# https://stat.ethz.ch/R-manual/R-devel/library/MASS/html/quine.html
#
# Pas fini !
